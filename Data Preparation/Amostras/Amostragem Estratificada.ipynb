# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
dados = pd.read_csv("base_scaled.csv")

# %%
dados.iloc[:,2:]
# Out:
#        TransactionDT  TransactionAmt  ProductCD     card1  card2     card3  \
# 0           0.460734        0.000692       0.25  0.072201  0.890  0.648855
# 1           0.526220        0.001288       0.25  0.461370  0.890  0.648855
# 2           0.778893        0.003656       0.00  0.588239  0.442  0.381679
# 3           0.869131        0.000724       0.25  0.477121  0.006  0.648855
# 4           0.890713        0.031116       0.00  0.288515  0.966  0.381679
# ...              ...             ...        ...       ...    ...       ...
# 60068       0.350772        0.001118       0.00  0.044091  0.886  0.381679
# 60069       0.483436        0.003656       0.00  0.887273  0.396  0.381679
# 60070       0.747160        0.012922       0.00  0.526845  0.924  0.381679
# 60071       0.921638        0.006442       0.00  0.263854  0.910  0.381679
# 60072       0.646452        0.003656       0.00  0.752932  0.762  0.381679
#
#           card4     card5  card6     addr1     addr2     dist1
# ...

# %%
x, _, y, _ = train_test_split(dados.iloc[:,1:], dados.iloc[:,:1], test_size = 0.5, stratify = dados.iloc[:,1:2])

# %%
y
# Out:
#        Unnamed: 0
# 26011      573724
# 13880      337465
# 58756      259484
# 34486      127343
# 36032      239633
# ...           ...
# 23725      539564
# 49258      266239
# 36119         853
# 44342      427573
# 1991       320855
#
# [30036 rows x 1 columns]

# %%
x.columns
# Out:
# Index(['isFraud', 'TransactionDT', 'TransactionAmt', 'ProductCD', 'card1',
#        'card2', 'card3', 'card4', 'card5', 'card6', 'addr1', 'addr2', 'dist1'],
#       dtype='object')
